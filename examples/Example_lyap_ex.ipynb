# %%
import dill
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(1, '../')

# %% [markdown]
# After running example_lyap_ex.py we get as output a pkl file which can be analyzed

# %%
with open('results/Lor63_N2000.pkl', 'rb') as reservoir:
    lor63_N2000 = dill.load(reservoir)

# %%
lor63_N2000.predict(15, acc = 3)
# Out:
# 6.123

# %% [markdown]
# Here we can plot the global lyapunov exponents of the predicting reservoir. Red dashes are the lyapunov exponents of the input system while blue lines are the LE of the reservoir.  The predicting reservoir should approximately reproduce the exponents of the system.

# %%
lor63_N2000.ifsave = True
lor63_N2000.plotLE(3)
lor63_N2000.LE[-1]
lor63_N2000.ifsave = False

# %%
#Kaplan-Yorke dimension of the reservoir
lor63_N2000.getKYDim()
# Out:
# 2.917366981466462

# %%
t = lor63_N2000.system.LE_t[:499]
fig = plt.figure(figsize = (10, 7))
plt.plot(t,lor63_N2000.LE[:, 0])
plt.plot(t, lor63_N2000.system.LE[:, 0])
plt.xlabel('time', fontsize = 16)
plt.ylabel('Lyapunov Exponent', fontsize = 16)
fig.savefig('Lor63_largest_LE.pdf', bbox_inches = 'tight')
